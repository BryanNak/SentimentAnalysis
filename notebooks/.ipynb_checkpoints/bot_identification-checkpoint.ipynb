# %%
import pandas as pd
import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

df = pd.read_parquet("hf://datasets/theArijitDas/Fake-Reviews-Dataset/data/train-00000-of-00001.parquet")

df.head()
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpcore\_sync\connection.py:156, in HTTPConnection._connect(self, request)
#     155 with Trace("start_tls", logger, request, kwargs) as trace:
# --> 156     stream = stream.start_tls(**kwargs)
#     157     trace.return_value = stream
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpcore\_backends\sync.py:154, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     150 exc_map: ExceptionMapping = {
#     151     socket.timeout: ConnectTimeout,
#     152     OSError: ConnectError,
#     153 }
# --> 154 with map_exceptions(exc_map):
#     155     try:
#
# File ~\anaconda3\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'huggingface.co'. (_ssl.c:1028)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# Cell In[2], line 6
#       3 from sklearn.ensemble import RandomForestClassifier
#       4 from sklearn.model_selection import RandomizedSearchCV
# ----> 6 df = pd.read_parquet("hf://datasets/theArijitDas/Fake-Reviews-Dataset/data/train-00000-of-00001.parquet")
#       8 df.head()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     666     use_nullable_dtypes = False
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
#     674     use_nullable_dtypes=use_nullable_dtypes,
#     675     dtype_backend=dtype_backend,
#     676     filesystem=filesystem,
#     677     **kwargs,
#     678 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\parquet.py:265, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     258 path_or_handle, handles, filesystem = _get_path_or_handle(
#     259     path,
#     260     filesystem,
#     261     storage_options=storage_options,
#     262     mode="rb",
#     263 )
#     264 try:
# --> 265     pa_table = self.api.parquet.read_table(
#     266         path_or_handle,
#     267         columns=columns,
#     268         filesystem=filesystem,
#     269         filters=filters,
#     270         **kwargs,
#     271     )
#     273     with catch_warnings():
#     274         filterwarnings(
#     275             "ignore",
#     276             "make_block is deprecated",
#     277             DeprecationWarning,
#     278         )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyarrow\parquet\core.py:1844, in read_table(source, columns, use_threads, schema, use_pandas_metadata, read_dictionary, binary_type, list_type, memory_map, buffer_size, partitioning, filesystem, filters, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, page_checksum_verification, arrow_extensions_enabled)
#    1832 def read_table(source, *, columns=None, use_threads=True,
#    1833                schema=None, use_pandas_metadata=False, read_dictionary=None,
#    1834                binary_type=None, list_type=None, memory_map=False, buffer_size=0,
#    (...)   1840                page_checksum_verification=False,
#    1841                arrow_extensions_enabled=True):
#    1843     try:
# -> 1844         dataset = ParquetDataset(
#    1845             source,
#    1846             schema=schema,
#    1847             filesystem=filesystem,
#    1848             partitioning=partitioning,
#    1849             memory_map=memory_map,
#    1850             read_dictionary=read_dictionary,
#    1851             binary_type=binary_type,
#    1852             list_type=list_type,
#    1853             buffer_size=buffer_size,
#    1854             filters=filters,
#    1855             ignore_prefixes=ignore_prefixes,
#    1856             pre_buffer=pre_buffer,
#    1857             coerce_int96_timestamp_unit=coerce_int96_timestamp_unit,
#    1858             decryption_properties=decryption_properties,
#    1859             thrift_string_size_limit=thrift_string_size_limit,
#    1860             thrift_container_size_limit=thrift_container_size_limit,
#    1861             page_checksum_verification=page_checksum_verification,
#    1862             arrow_extensions_enabled=arrow_extensions_enabled,
#    1863         )
#    1864     except ImportError:
#    1865         # fall back on ParquetFile for simple cases when pyarrow.dataset
#    1866         # module is not available
#    1867         if filters is not None:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyarrow\parquet\core.py:1401, in ParquetDataset.__init__(self, path_or_paths, filesystem, schema, filters, read_dictionary, binary_type, list_type, memory_map, buffer_size, partitioning, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, page_checksum_verification, arrow_extensions_enabled)
#    1397 if _is_path_like(path_or_paths):
#    1398     filesystem, path_or_paths = _resolve_filesystem_and_path(
#    1399         path_or_paths, filesystem, memory_map=memory_map
#    1400     )
# -> 1401     finfo = filesystem.get_file_info(path_or_paths)
#    1402     if finfo.type == FileType.Directory:
#    1403         self._base_dir = path_or_paths
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyarrow\_fs.pyx:616, in pyarrow._fs.FileSystem.get_file_info()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyarrow\error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyarrow\error.pxi:89, in pyarrow.lib.check_status()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyarrow\_fs.pyx:1523, in pyarrow._fs._cb_get_file_info()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyarrow\fs.py:319, in FSSpecHandler.get_file_info(self, paths)
#     317 for path in paths:
#     318     try:
# --> 319         info = self.fs.info(path)
#     320     except FileNotFoundError:
#     321         infos.append(FileInfo(path, FileType.NotFound))
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\hf_file_system.py:932, in HfFileSystem.info(self, path, refresh, revision, **kwargs)
#     910 def info(self, path: str, refresh: bool = False, revision: Optional[str] = None, **kwargs) -> dict[str, Any]:
#     911     """
#     912     Get information about a file or directory.
#     913
#    (...)    930
#     931     """
# --> 932     resolved_path = self.resolve_path(path, revision=revision)
#     933     path = resolved_path.unresolve()
#     934     expand_info = kwargs.get(
#     935         "expand_info", self.expand_info if self.expand_info is not None else False
#     936     )  # don't expose it as a parameter in the public API to follow the spec
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\hf_file_system.py:364, in HfFileSystem.resolve_path(self, path, revision)
#     362 repo_id = repo_id_with_namespace
#     363 path_in_repo = path_in_repo_with_namespace
# --> 364 repo_and_revision_exist, err = self._repo_and_revision_exist(repo_type, repo_id, revision)
#     365 if not repo_and_revision_exist:
#     366     if isinstance(err, (RepositoryNotFoundError, HFValidationError)):
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\hf_file_system.py:261, in HfFileSystem._repo_and_revision_exist(self, repo_type, repo_id, revision)
#     259 if (repo_type, repo_id, revision) not in self._repo_and_revision_exists_cache:
#     260     try:
# --> 261         self._api.repo_info(
#     262             repo_id, revision=revision, repo_type=repo_type, timeout=constants.HF_HUB_ETAG_TIMEOUT
#     263         )
#     264     except (RepositoryNotFoundError, HFValidationError) as e:
#     265         self._repo_and_revision_exists_cache[(repo_type, repo_id, revision)] = False, e
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\utils\_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      85         validate_repo_id(arg_value)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\hf_api.py:3285, in HfApi.repo_info(self, repo_id, revision, repo_type, timeout, files_metadata, expand, token)
#    3283 else:
#    3284     raise ValueError("Unsupported repo type.")
# -> 3285 return method(
#    3286     repo_id,
#    3287     revision=revision,
#    3288     token=token,
#    3289     timeout=timeout,
#    3290     expand=expand,  # type: ignore[arg-type]
#    3291     files_metadata=files_metadata,
#    3292 )
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\utils\_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      85         validate_repo_id(arg_value)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\huggingface_hub\hf_api.py:3090, in HfApi.dataset_info(self, repo_id, revision, timeout, files_metadata, expand, token)
#    3087 if expand:
#    3088     params["expand"] = expand
# -> 3090 r = get_session().get(path, headers=headers, timeout=timeout, params=params)
#    3091 hf_raise_for_status(r)
#    3092 data = r.json()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_client.py:1053, in Client.get(self, url, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1036 def get(
#    1037     self,
#    1038     url: URL | str,
#    (...)   1046     extensions: RequestExtensions | None = None,
#    1047 ) -> Response:
#    1048     """
#    1049     Send a `GET` request.
#    1050
#    1051     **Parameters**: See `httpx.request`.
#    1052     """
# -> 1053     return self.request(
#    1054         "GET",
#    1055         url,
#    1056         params=params,
#    1057         headers=headers,
#    1058         cookies=cookies,
#    1059         auth=auth,
#    1060         follow_redirects=follow_redirects,
#    1061         timeout=timeout,
#    1062         extensions=extensions,
#    1063     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_transports\default.py:249, in HTTPTransport.handle_request(self, request)
#     235 import httpcore
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~\anaconda3\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     160     value = typ()
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#     167     return exc is not value
#
# File ~\AppData\Roaming\Python\Python313\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     115     raise
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'huggingface.co'. (_ssl.c:1028)

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack, csr_matrix

x_train_raw, x_test_raw, y_train, y_test = train_test_split(
    df.loc[:, ~df.columns.isin(['label', 'category'])],
    df['label'],
    test_size=.2, random_state=42, shuffle=True
)

tfidf_vectorizer = TfidfVectorizer()
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train_raw['text'])
x_test_tfidf = tfidf_vectorizer.transform(x_test_raw['text'])

x_train_other = csr_matrix(x_train_raw.drop(columns=['text']).values)
x_test_other = csr_matrix(x_test_raw.drop(columns=['text']).values)

x_train_combined = hstack([x_train_tfidf, x_train_other])
x_test_combined = hstack([x_test_tfidf, x_test_other])

# %%
random_forest_rating = sklearn.ensemble.RandomForestClassifier()
param_grid = [{'n_estimators': [100, 300, 1000], 'max_features': ['sqrt', 'log2', .2, .5, 1], 'max_depth': [None, 10, 20, 40], 'min_samples_leaf':[1, 2, 5, 10], 'min_samples_split':[2,5,10]}]

# %%
from sklearn.metrics import accuracy_score, f1_score
rand_search_cv_rating = RandomizedSearchCV(random_forest_rating, param_grid, n_jobs=4, scoring=['accuracy','precision', 'recall', 'f1', 'roc_auc'], refit='f1', verbose=3)
rand_search_cv_rating.fit(x_train_combined, y_train)

y_pred_rating = rand_search_cv_rating.predict(x_test_combined)
f1_refit_rating = f1_score(y_test, y_pred_rating)

print(f"f1 score of RandomForestClassifier w/ RandomizedSearchCV: {f1_refit_rating}\n")
print(f"Best params: {rand_search_cv_rating.best_estimator_}\n")

print(accuracy_score(y_test, y_pred_rating))

# %% [markdown]
# ## saving best random forest model

# %%
from joblib import dump
dump(rand_search_cv_rating.best_estimator_, 'random_forest_with_rating.joblib')

# %% [markdown]
# ## XGBoost

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

train = pd.read_csv('../data/bot_identification/train.csv', sep=';')
test = pd.read_csv('../data/bot_identification/test.csv', sep=';')

encoder = OneHotEncoder()
x_train = train['text']
x_test = test['text']

y_train = pd.DataFrame(train['account.type'])
y_test = pd.DataFrame(test['account.type'])
y_train_matrix = encoder.fit_transform(y_train).toarray().tolist()
y_test_matrix = encoder.transform(y_test).toarray().tolist()

def get_single_label(encoded):
    y_labels = []
    for isBot, isntBot in encoded:
        y_labels.append(int(isBot))
    return y_labels
    
y_train_encoded = get_single_label(y_train_matrix)
y_test_encoded = get_single_label(y_test_matrix)

tfidf_vectorizer = TfidfVectorizer()
x_train_vectorized = tfidf_vectorizer.fit_transform(x_train)
x_test_vectorized = tfidf_vectorizer.transform(x_test)

# %%
from xgboost import XGBClassifier

xgbclf = XGBClassifier()

param_dist = {
    "n_estimators": [100, 200, 300, 500, 800, 1200],
    "max_depth": [3, 4, 5, 6, 8, 10, 13],
    "learning_rate": [0.01, 0.03, 0.05, 0.1, 0.2, .035],
    "subsample": [0.6, 0.7, 0.8, 0.9, .85, 1.0],
    "colsample_bytree": [0.5, .55, 0.6, 0.7, 0.8, 1.0],
    "gamma": [0, 0.1, 0.3, 0.5, 1],
    "min_child_weight": [1, 2, 3, 5, 7, 10],
    "reg_alpha": [0, 0.01, 0.1, .3, 1, 10],
    "reg_lambda": [0, 0.1, 1, 5, 10, 20],
    "scale_pos_weight": [1, 2, 2.5, 5, 10]
}

# %%
rand_search_cv_xgb = RandomizedSearchCV(xgbclf, param_dist, n_jobs=4, scoring=['accuracy','precision', 'recall', 'f1', 'roc_auc'], refit='f1', verbose=3)
rand_search_cv_xgb.fit(x_train_vectorized, y_train_encoded)

# %%
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.feature_extraction.text import TfidfVectorizer
from xgboost import XGBClassifier

# Get best params from completed RandomizedSearchCV
# best_xgb_params = rand_search_cv_xgb.best_params_

features = FeatureUnion([
    (
        "word_tfidf",
        TfidfVectorizer(
            analyzer="word",
            ngram_range=(1, 2),
            max_features=50000,
            min_df=2,
            max_df=0.95,
            sublinear_tf=True,
            lowercase=True
        )
    ),
    (
        "char_tfidf",
        TfidfVectorizer(
            analyzer="char_wb",
            ngram_range=(3, 5),
            max_features=50000,
            min_df=2,
            sublinear_tf=True,
            lowercase=True
        )
    )
])

xgb = XGBClassifier(
    subsample=.85,
    scale_pos_weight=2.5,
    reg_lambda=0,
    reg_alpha=0.3,
    n_estimators=1200,
    min_child_weight=2,
    max_depth=13,
    learning_rate=0.035,
    gamma=1.0,
    colsample_bytree=0.55,
    n_jobs=-1)

# xgb = XGBClassifier(
#     **best_xgb_params,
#     eval_metric="logloss",
#     random_state=42,
#     n_jobs=-1
# )

pipeline = Pipeline([
    ("features", features),
    ("xgb", xgb)
])

# %%
pipeline = pipeline.fit(x_train, y_train_encoded)

# %%
pipeline_pred = pipeline.predict(x_test)
f1 = f1_score(y_test_encoded, pipeline_pred)

# %% [markdown]
# ## saving xgb classifier and tfidf vectorizer used

# %%
import joblib
from joblib import dump

filename = f"../models/bot_id_xgb_tree.joblib"

joblib.dump(pipeline, filename)
